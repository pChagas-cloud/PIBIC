# %%
#importando
import pandas as pd
import numpy as np
import math

# %%
#setando o dataframe

df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.switzerland.data', 
                         names = ['idade',
                                 'sexo',
                                 'tipo_de_dores',
                                 'pressao_sanguinea',
                                 'colesterol',
                                 'acucar_no_sangue',
                                 'rest_ecg?',
                                 'maior_indice_de_batimentos',
                                 'exang',
                                 'oldpeak',
                                 'slope',
                                 'ca',
                                 'thal',
                                'num'])
df
# Out:
#      idade  sexo  tipo_de_dores pressao_sanguinea  colesterol  \
# 0       32     1              1                95           0
# 1       34     1              4               115           0
# 2       35     1              4                 ?           0
# 3       36     1              4               110           0
# 4       38     0              4               105           0
# ..     ...   ...            ...               ...         ...
# 118     70     1              4               115           0
# 119     70     1              4               140           0
# 120     72     1              3               160           0
# 121     73     0              3               160           0
# 122     74     1              2               145           0
#
#     acucar_no_sangue rest_ecg? maior_indice_de_batimentos exang oldpeak slope  \
# 0                  ?         0                        127     0      .7     1
# 1                  ?         ?                        154     0      .2     1
# 2                  ?         0                        130     1       ?     ?
# 3                  ?         0                        125     1       1     2
# 4                  ?         0                        166     0     2.8     1
# ..               ...       ...                        ...   ...     ...   ...
# 118                0         1                         92     1       0     2
# 119                1         0                        157     1       2     2
# 120                ?         2                        114     0     1.6     2
# 121                0         1                        121     0       0     1
# 122                ?         1                        123     0     1.3     1
#
#     ca thal  num
# 0    ?    ?    1
# 1    ?    ?    1
# 2    ?    7    3
# 3    ?    6    1
# 4    ?    ?    2
# ..  ..  ...  ...
# 118  ?    7    1
# 119  ?    7    3
# 120  2    ?    0
# 121  ?    3    1
# 122  ?    ?    1
#
# [123 rows x 14 columns]

# %%
#criando ferramentas


class tratar_dados_faltantes:

    def conferir_faltantes(coluna, identidade_nulo):
        dados = coluna
        valores_nulos = []
        x = 0
        for i in dados:
            if dados[x] == identidade_nulo:
                return True
            x = x + 1
        return False
    
    def conferir_dados(coluna):
        try:
            x = 0
            for i in coluna:
                coluna[x] = int(coluna[x])
                x = x + 1
            valor_max = f"O valor máximo encontrado foi: {coluna.max()}"
            valor_min = f"O valor mínimo encontrado foi: {coluna.min()}"
            valor_med = f"A média entre os valores é: {coluna.mean()}"
            desvio_padrao = f"O desvio padrão é: {coluna.std()}"
            variancia = f"A variância é: {coluna.var()}"
            desvio_absoluto = f"O desvio absoluto é: {coluna.mad()}"
            mediana = f"A mediana é igual a {coluna.median()}"
            valores = [valor_max, valor_min, valor_med, desvio_padrao, variancia, desvio_absoluto, mediana]
            return valores
        
        except ValueError:
            print('Ops, algum erro ocorreu!')
        
    
    def tratar_faltantes(coluna, identidade_nulo):
        dados = coluna
        valores_normais = []
        x = 0
        for i in dados:
            if dados[x] != identidade_nulo:
                valores_normais.append(dados[x])
            x = x + 1

        valores_normais = np.array(valores_normais).astype(np.float)

        x = 0

        for i in dados:
            if dados[x] == identidade_nulo:
                dados[x] = int(valores_normais.mean())
            x = x + 1
            
    def checar_dataset(dataset, identidade_nulo):
        df = dataset
        ccdf = [] #ccdf = colunas com dados faltantes
        for i in df:
            is_null = tratar_dados_faltantes.conferir_faltantes(df[i], identidade_nulo)
            ccdf.append(is_null)
        return ccdf
    
    def tratar_dataset(dataset, identidade_nulo):
        df = dataset
        for i in df:
            if tratar_dados_faltantes.conferir_faltantes(df[i], identidade_nulo) == True:
                tratar_dados_faltantes.tratar_faltantes(df[i], identidade_nulo)
                
                
    def mostrar_dados(coluna):
        try:
            x = 0
            for i in coluna:
                coluna[x] = int(coluna[x])
                x = x + 1
            valor_max = ["valor máximo encontrado", coluna.max()]
            valor_min = ["valor mínimo encontrado", coluna.min()]
            valor_med = ["média entre valores", coluna.mean()]
            desvio_padrao = ["desvio padrão", coluna.std()]
            variancia = ["A variância é:", coluna.var()]
            desvio_absoluto = ["Desvio absoluto", coluna.mad()]
            mediana = ["Mediana", coluna.median()]
            valores = [valor_max, valor_min, valor_med, desvio_padrao, variancia, desvio_absoluto, mediana]
            valores = pd.DataFrame(valores)
            return valores
        except ValueError:
            print('Ops, algum erro ocorreu!')
            
    def listar_novos_dados(dados):
        try:
            data = []
            for coluna in df:
                data.append(tratar_dados_faltantes.mostrar_dados(df[coluna]))
            x = 0
            for i in data:
                print('='*50)
                print('Coluna {}'.format(x+1))
                print('='*50)
                print(data[x])
                x = x + 1
        except ValueError:
            print('Ops, algum erro ocorreu!')
            print('Você deve ter inserido os dados errados...')
            print('Tente:')
            print('(1) tratar os dados com a função "tratar_dataset"')
            print('(2) procurar colunas faltantes com a função "checar_dataset"')
            print('\n')
            
            
            
class tratar_quantidade_de_dados():
    
    def setar_valores(valores):
        pass
        
    
    def reduzir_valor_dos_dados(data_frame):
        colunas__ = []
        for coluna in df:
            dataset = df[coluna]
            for item in dataset:
                if float(item) > 100:
                    if coluna not in colunas__:
                        colunas__.append(coluna)
        valores_f = []
        for coluna__ in colunas__:
            dataset = df[coluna__]
            z = 0
            for i in dataset:
                dataset[z] = int(dataset[z])
                z = z + 1
            media = df[coluna__].mean()
            desvio_padrao = df[coluna__].std()
            novos_valores = []
            for valor in dataset:
                novo_valor = (valor - media)/desvio_padrao
                novos_valores.append(novo_valor)
            valores_f.append(novos_valores)
        return valores_f
    
    def reduzir_numero_de_dados(coluna):
        pass
    

            
        print(colunas__)

# %%
tratar_dados_faltantes.tratar_dataset(df, '?')
tratar_quantidade_de_dados.reduzir_valor_dos_dados(df)[1][0]
# Out:
# C:\Users\Estudos\AppData\Local\Temp/ipykernel_2504/2625152526.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[z] = int(dataset[z])
# 0.21055220471827246

# %%
nova_pressao = tratar_quantidade_de_dados.reduzir_valor_dos_dados(df)[1]
counter = 0
for valor in df['pressao_sanguinea']:
    df['pressao_sanguinea'][counter] = nova_pressao[counter]
    counter = counter + 1
# Out:
# C:\Users\Estudos\AppData\Local\Temp/ipykernel_2504/2625152526.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[z] = int(dataset[z])
# C:\Users\Estudos\AppData\Local\Temp/ipykernel_2504/1036496538.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pressao_sanguinea'][counter] = nova_pressao[counter]

# %%
tratar_dados_faltantes.tratar_dataset(df, '?')
df
# Out:
#      idade  sexo  tipo_de_dores pressao_sanguinea  colesterol  \
# 0       32     1              1                95           0
# 1       34     1              4               115           0
# 2       35     1              4               130           0
# 3       36     1              4               110           0
# 4       38     0              4               105           0
# ..     ...   ...            ...               ...         ...
# 118     70     1              4               115           0
# 119     70     1              4               140           0
# 120     72     1              3               160           0
# 121     73     0              3               160           0
# 122     74     1              2               145           0
#
#     acucar_no_sangue rest_ecg? maior_indice_de_batimentos exang oldpeak slope  \
# 0                  0         0                        127     0      .7     1
# 1                  0         0                        154     0      .2     1
# 2                  0         0                        130     1       0     1
# 3                  0         0                        125     1       1     2
# 4                  0         0                        166     0     2.8     1
# ..               ...       ...                        ...   ...     ...   ...
# 118                0         1                         92     1       0     2
# 119                1         0                        157     1       2     2
# 120                0         2                        114     0     1.6     2
# 121                0         1                        121     0       0     1
# 122                0         1                        123     0     1.3     1
#
#     ca thal  num
# 0    1    5    1
# 1    1    5    1
# 2    1    7    3
# 3    1    6    1
# 4    1    5    2
# ..  ..  ...  ...
# 118  1    7    1
# 119  1    7    3
# 120  2    5    0
# 121  1    3    1
# 122  1    5    1
#
# [123 rows x 14 columns]

# %%
tratar_dados_faltantes.tratar_dataset(df, '?')
print(tratar_dados_faltantes.listar_novos_dados(df))
#rolar um pouqinnho para baixo (:
# Out:
# C:\Users\Estudos\AppData\Local\Temp/ipykernel_2504/2625152526.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados[x] = int(valores_normais.mean())
# C:\Users\Estudos\AppData\Local\Temp/ipykernel_2504/2625152526.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coluna[x] = int(coluna[x])
# C:\Users\Estudos\AppData\Local\Temp/ipykernel_2504/2625152526.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coluna[x] = int(coluna[x])
# C:\Users\Estudos\AppData\Local\Temp/ipykernel_2504/2625152526.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coluna[x] = int(coluna[x])
# C:\Users\Estudos\AppData\Local\Temp/ipykernel_2504/2625152526.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coluna[x] = int(coluna[x])
# C:\Users\Estudos\AppData\Local\Temp/ipykernel_2504/2625152526.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coluna[x] = int(coluna[x])
# C:\Users\Estudos\AppData\Local\Temp/ipykernel_2504/2625152526.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coluna[x] = int(coluna[x])
# C:\Users\Estudos\AppData\Local\Temp/ipykernel_2504/2625152526.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coluna[x] = int(coluna[x])
# C:\Users\Estudos\AppData\Local\Temp/ipykernel_2504/2625152526.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coluna[x] = int(coluna[x])
# C:\Users\Estudos\AppData\Local\Temp/ipykernel_2504/2625152526.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coluna[x] = int(coluna[x])
# Ops, algum erro ocorreu!
# ==================================================
# Coluna 1
# ==================================================
#                          0          1
# 0  valor máximo encontrado  74.000000
# 1  valor mínimo encontrado  32.000000
# 2      média entre valores  55.317073
# 3            desvio padrão   9.032108
# 4           A variância é:  81.578968
# 5          Desvio absoluto   7.145350
# 6                  Mediana  56.000000
# ==================================================
# Coluna 2
# ==================================================
#                          0         1
# 0  valor máximo encontrado  1.000000
# 1  valor mínimo encontrado  0.000000
# 2      média entre valores  0.918699
# 3            desvio padrão  0.274414
# 4           A variância é:  0.075303
# 5          Desvio absoluto  0.149382
# 6                  Mediana  1.000000
# ==================================================
# Coluna 3
# ==================================================
#                          0         1
# 0  valor máximo encontrado  4.000000
# 1  valor mínimo encontrado  1.000000
# 2      média entre valores  3.699187
# 3            desvio padrão  0.688726
# 4           A variância é:  0.474344
# 5          Desvio absoluto  0.479344
# 6                  Mediana  4.000000
# ==================================================
# Coluna 4
# ==================================================
#                          0           1
# 0  valor máximo encontrado  200.000000
# 1  valor mínimo encontrado   80.000000
# 2      média entre valores  130.203252
# 3            desvio padrão   22.373491
# 4           A variância é:  500.573104
# 5          Desvio absoluto         NaN
# 6                  Mediana  130.000000
# ==================================================
# Coluna 5
# ==================================================
#                          0    1
# 0  valor máximo encontrado  0.0
# 1  valor mínimo encontrado  0.0
# 2      média entre valores  0.0
# 3            desvio padrão  0.0
# 4           A variância é:  0.0
# 5          Desvio absoluto  0.0
# 6                  Mediana  0.0
# ==================================================
# Coluna 6
# ==================================================
#                          0         1
# 0  valor máximo encontrado  1.000000
# 1  valor mínimo encontrado  0.000000
# 2      média entre valores  0.040650
# 3            desvio padrão  0.198287
# 4           A variância é:  0.039318
# 5          Desvio absoluto       NaN
# 6                  Mediana  0.000000
# ==================================================
# Coluna 7
# ==================================================
#                          0         1
# 0  valor máximo encontrado  2.000000
# 1  valor mínimo encontrado  0.000000
# 2      média entre valores  0.357724
# 3            desvio padrão  0.588553
# 4           A variância é:  0.346395
# 5          Desvio absoluto       NaN
# 6                  Mediana  0.000000
# ==================================================
# Coluna 8
# ==================================================
#                          0           1
# 0  valor máximo encontrado  182.000000
# 1  valor mínimo encontrado   60.000000
# 2      média entre valores  121.552846
# 3            desvio padrão   25.870802
# 4           A variância é:  669.298414
# 5          Desvio absoluto         NaN
# 6                  Mediana  121.000000
# ==================================================
# Coluna 9
# ==================================================
#                          0         1
# 0  valor máximo encontrado  1.000000
# 1  valor mínimo encontrado  0.000000
# 2      média entre valores  0.439024
# 3            desvio padrão  0.498298
# 4           A variância é:  0.248301
# 5          Desvio absoluto       NaN
# 6                  Mediana  0.000000
# ==================================================
# Coluna 10
# ==================================================
# None
# ==================================================
# Coluna 11
# ==================================================
#                          0         1
# 0  valor máximo encontrado  3.000000
# 1  valor mínimo encontrado  1.000000
# 2      média entre valores  1.691057
# 3            desvio padrão  0.641848
# 4           A variância é:  0.411969
# 5          Desvio absoluto       NaN
# 6                  Mediana  2.000000
# ==================================================
# Coluna 12
# ==================================================
#                          0         1
# 0  valor máximo encontrado  2.000000
# 1  valor mínimo encontrado  1.000000
# 2      média entre valores  1.024390
# 3            desvio padrão  0.154888
# 4           A variância é:  0.023990
# 5          Desvio absoluto       NaN
# 6                  Mediana  1.000000
# ==================================================
# Coluna 13
# ==================================================
#                          0         1
# 0  valor máximo encontrado  7.000000
# 1  valor mínimo encontrado  3.000000
# 2      média entre valores  5.455285
# 3            desvio padrão  1.368570
# 4           A variância é:  1.872984
# 5          Desvio absoluto       NaN
# 6                  Mediana  5.000000
# ==================================================
# Coluna 14
# ==================================================
#                          0         1
# 0  valor máximo encontrado  4.000000
# 1  valor mínimo encontrado  0.000000
# 2      média entre valores  1.804878
# 3            desvio padrão  1.013503
# 4           A variância é:  1.027189
# 5          Desvio absoluto  0.862978
# 6                  Mediana  2.000000
# None
# C:\Users\Estudos\AppData\Local\Temp/ipykernel_2504/2625152526.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coluna[x] = int(coluna[x])
# C:\Users\Estudos\AppData\Local\Temp/ipykernel_2504/2625152526.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coluna[x] = int(coluna[x])
# C:\Users\Estudos\AppData\Local\Temp/ipykernel_2504/2625152526.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coluna[x] = int(coluna[x])
# C:\Users\Estudos\AppData\Local\Temp/ipykernel_2504/2625152526.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coluna[x] = int(coluna[x])

# %%
df
df.columns
# Out:
# Index(['idade', 'sexo', 'tipo_de_dores', 'pressao_sanguinea', 'colesterol',
#        'acucar_no_sangue', 'rest_ecg?', 'maior_indice_de_batimentos', 'exang',
#        'oldpeak', 'slope', 'ca', 'thal', 'num'],
#       dtype='object')

# %%
dados = []
limite = len(df.columns)
index = 0
dado = []
for var in df:
    dado = []
    while index < limite:
        dado.append(df[var][index])
print(dado)
